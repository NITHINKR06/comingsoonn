# %% [markdown]
# <a href="https://colab.research.google.com/github/NITHINKR06/comingsoonn/blob/main/comingsoon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hybrid Machine Learning Based Intrusion Detection System
#
# ## 1. Introduction
#
# ## 2. Dataset Description (NSL-KDD)
#
# ## 3. Features and Labels
#
# ## 4. Preprocessing Strategy
#
# ## 5. Machine Learning Models
#
# ## 6. Evaluation Metrics

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt

print("Setup complete")
# Out:
# Setup complete
